# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
# Load the dataset with the correct encoding
df = pd.read_csv('datasets\\Global_terrorist.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
import folium

# %% [markdown]
# <H1>Filtering Data</H1>

# %%
df['natlty1_txt'].value_counts()
# Out:
# natlty1_txt
# Iraq                                  24113
# Pakistan                              13900
# India                                 12098
# Afghanistan                           10931
# Colombia                               7922
#                                       ...
# Commonwealth of Independent States        1
# St. Lucia                                 1
# Saba (Netherlands Antilles)               1
# Tuvalu                                    1
# Marshall Islands                          1
# Name: count, Length: 215, dtype: int64

# %%
filters = df[df['natlty1_txt'] == 'Pakistan']

# %%
filters['region_txt'].value_counts()
# Out:
# region_txt
# South Asia                    13866
# Middle East & North Africa       13
# Western Europe                    9
# Southeast Asia                    8
# Sub-Saharan Africa                2
# South America                     1
# Eastern Europe                    1
# Name: count, dtype: int64

# %%
filter1 = df[df['region_txt'] == 'South Asia']

# %%
filter1['targsubtype1_txt'].value_counts()
# Out:
# targsubtype1_txt
# Police Security Forces/Officers                      3651
# Unnamed Civilian/Unspecified                         2957
# Police Patrol (including vehicles and convoys)       1971
# Government Personnel (excluding police, military)    1919
# Police Building (headquarters, station, school)      1895
#                                                      ...
# Oil Tanker                                              3
# Military Weaponry                                       3
# Fire Fighter/Truck                                      3
# Subway                                                  2
# Internet Infrastructure                                 1
# Name: count, Length: 109, dtype: int64

# %%
filter2['targsubtype1_txt'] == 'Police Security Forces/Officers'
# Out:
# 71651     False
# 71653     False
# 71654     False
# 71655     False
# 71658     False
#           ...
# 181670    False
# 181671    False
# 181674    False
# 181679    False
# 181687    False
# Name: targsubtype1_txt, Length: 40806, dtype: bool

# %%
filter3 = filter2[filter2['targsubtype1_txt'] == 'Police Security Forces/Officers']

# %%
filter3['nkill'] >= 10
# Out:
# 71701     False
# 71776     False
# 71839     False
# 72019     False
# 72036     False
#           ...
# 180596    False
# 180753    False
# 181096    False
# 181498    False
# 181592    False
# Name: nkill, Length: 2681, dtype: bool

# %%
filter4 = filter3[filter3['nkill'] >= 10]

# %%
filter4['attacktype1_txt'].value_counts()
# Out:
# attacktype1_txt
# Bombing/Explosion              74
# Armed Assault                  14
# Hostage Taking (Kidnapping)    14
# Unknown                         9
# Assassination                   1
# Name: count, dtype: int64

# %%
filter4['attacktype1_txt'] == 'Bombing/Explosion'
# Out:
# 76591      True
# 77149     False
# 77164     False
# 77246      True
# 78068      True
#           ...
# 175906     True
# 175907     True
# 175908     True
# 176499    False
# 179635     True
# Name: attacktype1_txt, Length: 112, dtype: bool

# %%
filter5 = filter4[filter4['attacktype1_txt'] == 'Bombing/Explosion']

# %%
final = filter5.groupby(['latitude','longitude']).size().reset_index(name='incident_count')

# %%
final
# Out:
#      latitude  longitude  incident_count
# 0   14.543970  49.124580               1
# 1   15.666667  43.950000               1
# 2   30.022924  31.185192               1
# 3   30.510054  47.778095               1
# 4   32.469238  44.416637               2
# 5   32.777344  44.289352               2
# 6   33.163559  43.863106               1
# 7   33.303566  44.371773              10
# 8   33.349159  43.784199               1
# 9   33.414598  43.455254               1
# 10  33.420948  43.295662               7
# 11  33.515244  36.292084               1
# 12  33.540672  44.251266               1
# 13  33.617965  44.572428               1
# 14  33.633896  42.832081               1
# 15  33.693409  44.796085               1
# 16  33.773349  45.149451               1
# 17  33.864799  42.536385               2
# 18  33.953167  44.921906               2
# 19  34.208416  43.890713               1
# 20  34.271034  45.163567               2
# 21  34.458889  43.791004               1
# 22  34.621521  43.668377               3
# 23  35.326122  43.780811               1
# 24  35.452110  44.375465               4
# 25  35.700397  43.280434               1
# 26  35.904295  43.058433               1
# 27  35.964956  40.902176               1
# 28  36.192589  44.004623               1
# 29  36.228695  43.105652               1
# 30  36.229574  42.236244               1
# 31  36.319386  41.861473               1
# 32  36.354145  43.143570              10
# 33  36.503593  40.740627               2
# 34  36.508533  42.842224               1
# 35  36.562222   3.594444               1
# 36  36.723980   3.670848               1
# 37  36.803982  42.093945               1
# 38  37.340200  41.893400               1

# %% [markdown]
# <H1>Use of FOLIUM FOR GEOSPATIAL</H1>

# %%
from folium.plugins import HeatMap

# %% [markdown]
# <h1>Converting PANDAS df into Python List</h1>

# %%
final['normalize_data'] = final['incident_count'] - final['incident_count'].min() / final['incident_count'].max() - final['incident_count'].min()
heat_data = final[['latitude','longitude','normalize_data']].values.tolist()

# %% [markdown]
# <h1>Creating a base map</h1>

# %%
my_loc = folium.Map(location =[30,40],zoom_start =4)

# %% [markdown]
# <H1>Add Heatmap Layer</H1>

# %%
HeatMap(heat_data).add_to(my_loc)

# %%
my_loc.save('terrorism_bombing2.html')
print("Data Successfully Saved to terrorism_bombing2.html")
# Out:
# Data Successfully Saved to terrorism_bombing2.html

# %%
my_loc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b5a3c7041f5e37247febfd9c55e2837 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b5a3c7041f5e37247febfd9c55e2837&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b5a3c7041f5e37247febfd9c55e2837 = L.map(
#                 &quot;map_3b5a3c7041f5e37247febfd9c55e2837&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e84cac19699ed26ba48add435265993b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e84cac19699ed26ba48add435265993b.addTo(map_3b5a3c7041f5e37247febfd9c55e2837);
#
#
#             var heat_map_3d8edb8ccbdafae5417dde868477284c = L.heatLayer(
#                 [[14.54397, 49.12458, -0.09999999999999998], [15.666667, 43.95, -0.09999999999999998], [30.022924, 31.185192, -0.09999999999999998], [30.510054, 47.778095, -0.09999999999999998], [32.469238, 44.416637, 0.8999999999999999], [32.777344, 44.289352, 0.8999999999999999], [33.163559, 43.863106, -0.09999999999999998], [33.303566, 44.371773, 8.9], [33.349159, 43.784199, -0.09999999999999998], [33.414598, 43.455254, -0.09999999999999998], [33.420948, 43.295662, 5.9], [33.515244, 36.292084, -0.09999999999999998], [33.540672, 44.251266, -0.09999999999999998], [33.617965, 44.572428, -0.09999999999999998], [33.633896, 42.832081, -0.09999999999999998], [33.693409, 44.796085, -0.09999999999999998], [33.773349, 45.149451, -0.09999999999999998], [33.864799, 42.536385, 0.8999999999999999], [33.953167, 44.921906, 0.8999999999999999], [34.208416, 43.890713, -0.09999999999999998], [34.271034, 45.163567, 0.8999999999999999], [34.458889, 43.791004, -0.09999999999999998], [34.621521, 43.668377, 1.9], [35.326122, 43.780811, -0.09999999999999998], [35.45211, 44.375465, 2.9], [35.700397, 43.280434, -0.09999999999999998], [35.904295, 43.058433, -0.09999999999999998], [35.964956, 40.902176, -0.09999999999999998], [36.192589, 44.004623, -0.09999999999999998], [36.228695, 43.105652, -0.09999999999999998], [36.229574, 42.236244, -0.09999999999999998], [36.319386, 41.861473, -0.09999999999999998], [36.354145, 43.14357, 8.9], [36.503593, 40.740627, 0.8999999999999999], [36.508533, 42.842224, -0.09999999999999998], [36.562222, 3.594444, -0.09999999999999998], [36.72398, 3.670848, -0.09999999999999998], [36.803982, 42.093945, -0.09999999999999998], [37.3402, 41.8934, -0.09999999999999998]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_3d8edb8ccbdafae5417dde868477284c.addTo(map_3b5a3c7041f5e37247febfd9c55e2837);
#
#
#             tile_layer_e84cac19699ed26ba48add435265993b.addTo(map_3b5a3c7041f5e37247febfd9c55e2837);
#
#
#             heat_map_3d8edb8ccbdafae5417dde868477284c.addTo(map_3b5a3c7041f5e37247febfd9c55e2837);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
