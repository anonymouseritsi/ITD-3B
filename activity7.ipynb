# %% [markdown]
# <h1>Chicago Crimes</h1>
# <H2>Analyst: Richie Alcantara</H2>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('datasets\\Chicago_Crimes.csv')

# %%
df
# Out:
#               ID Case Number                    Date                  Block  \
# 0       13439321    JH237424  04/14/2024 12:00:00 AM    040XX S PRAIRIE AVE
# 1       13437420    JH234779  04/14/2024 12:00:00 AM      023XX W CERMAK RD
# 2       13428676    JH224478  04/14/2024 12:00:00 AM    043XX W LE MOYNE ST
# 3       13429357    JH225293  04/14/2024 12:00:00 AM       039XX W ADAMS ST
# 4       13430098    JH226395  04/14/2024 12:00:00 AM       011XX W 112TH PL
# ...          ...         ...                     ...                    ...
# 249118  13805239    JJ217509  04/12/2025 12:00:00 AM     029XX W LOGAN BLVD
# 249119  13804023    JJ215813  04/12/2025 12:00:00 AM    094XX S HARVARD AVE
# 249120  13803926    JJ215943  04/12/2025 12:00:00 AM  084XX S VINCENNES AVE
# 249121  13803475    JJ215338  04/12/2025 12:00:00 AM    050XX S ABERDEEN ST
# 249122  13804512    JJ216668  04/12/2025 12:00:00 AM    012XX W CARROLL AVE
#
# ...

# %%
df['Updated On'] = pd.to_datetime(df['Updated On'],dayfirst=True,errors = 'coerce')

# %%
df['Month'] = df['Updated On'].dt.month

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                59201
# BATTERY                              44579
# CRIMINAL DAMAGE                      27094
# ASSAULT                              22615
# MOTOR VEHICLE THEFT                  19604
# OTHER OFFENSE                        16781
# DECEPTIVE PRACTICE                   14991
# BURGLARY                              8443
# ROBBERY                               8200
# WEAPONS VIOLATION                     7164
# NARCOTICS                             6627
# CRIMINAL TRESPASS                     5045
# OFFENSE INVOLVING CHILDREN            1597
# CRIMINAL SEXUAL ASSAULT               1573
# SEX OFFENSE                           1210
# PUBLIC PEACE VIOLATION                1006
# INTERFERENCE WITH PUBLIC OFFICER       771
# HOMICIDE                               553
# STALKING                               520
# ARSON                                  452
# PROSTITUTION                           287
# ...

# %%
theft = df[df['Primary Type']=='THEFT']
battery = df[df['Primary Type']=='BATTERY']
CRIMINAL_DAMAGE = df[df['Primary Type']=='CRIMINAL DAMAGE']
ASSAULT = df[df['Primary Type']=='ASSAULT']
MOTOR_VEHICLE_THEFT = df[df['Primary Type']=='MOTOR VEHICLE THEFT']
OTHER_OFFENSE = df[df['Primary Type']=='OTHER OFFENSE']
DECEPTIVE_PRACTICE = df[df['Primary Type']=='DECEPTIVE PRACTICE']
BURGLARY = df[df['Primary Type']=='BURGLARY']
ROBBERY = df[df['Primary Type']=='ROBBERY']
WEAPONS_VIOLATION = df[df['Primary Type']=='WEAPONS VIOLATION']
NARCOTICS = df[df['Primary Type']=='NARCOTICS']
CRIMINAL_TRESPASS = df[df['Primary Type']=='CRIMINAL TRESPASS']
OFFENSE_INVOLVING_CHILDREN = df[df['Primary Type']=='OFFENSE INVOLVING CHILDREN']
CRIMINAL_SEXUAL_ASSAULT = df[df['Primary Type']=='CRIMINAL SEXUAL ASSAULT']
SEX_OFFENSE = df[df['Primary Type']=='SEX OFFENSE']
PUBLIC_PEACE_VIOLATION = df[df['Primary Type']=='PUBLIC PEACE VIOLATION']
INTERFERENCE_WITH_PUBLIC_OFFICER = df[df['Primary Type']=='INTERFERENCE WITH PUBLIC OFFICER']
HOMICIDE = df[df['Primary Type']=='HOMICIDE']
STALKING = df[df['Primary Type']=='STALKING']
ARSON = df[df['Primary Type']=='ARSON']
PROSTITUTION = df[df['Primary Type']=='PROSTITUTION']
CONCEALED_CARRY_LICENSE_VIOLATION = df[df['Primary Type']=='CONCEALED CARRY LICENSE VIOLATION']
LIQUOR_LAW_VIOLATION = df[df['Primary Type']=='LIQUOR LAW VIOLATION']
INTIMIDATION = df[df['Primary Type']=='INTIMIDATION']
KIDNAPPING = df[df['Primary Type']=='KIDNAPPING']
OBSCENITY = df[df['Primary Type']=='OBSCENITY']
HUMAN_TRAFFICKING = df[df['Primary Type']=='HUMAN TRAFFICKING']
GAMBLING = df[df['Primary Type']=='GAMBLING']
PUBLIC_INDECENCY = df[df['Primary Type']=='PUBLIC INDECENCY']
OTHER_NARCOTIC_VIOLATION = df[df['Primary Type']=='OTHER NARCOTIC VIOLATION']
NON_CRIMINAL = df[df['Primary Type']=='NON-CRIMINAL']

# %%
theft_loc = theft[theft['Location Description']=='STREET']
battery_loc = battery[battery['Location Description']=='STREET']
cd_loc = CRIMINAL_DAMAGE[CRIMINAL_DAMAGE['Location Description']=='STREET']
ASSAULT_loc = ASSAULT[ASSAULT['Location Description']=='STREET']
MOTOR_VEHICLE_THEFT_loc = MOTOR_VEHICLE_THEFT[MOTOR_VEHICLE_THEFT['Location Description']=='STREET']
OTHER_OFFENSE_loc = OTHER_OFFENSE[OTHER_OFFENSE['Location Description']=='STREET']
DECEPTIVE_PRACTICE_loc = DECEPTIVE_PRACTICE[DECEPTIVE_PRACTICE['Location Description']=='STREET']
BURGLARY_loc = BURGLARY[BURGLARY['Location Description']=='STREET']
ROBBERY_loc = ROBBERY[ROBBERY['Location Description']=='STREET']
WEAPONS_VIOLATION_loc = WEAPONS_VIOLATION[WEAPONS_VIOLATION['Location Description']=='STREET']
NARCOTICS_loc = NARCOTICS[NARCOTICS['Location Description']=='STREET']
CRIMINAL_TRESPASS_loc = CRIMINAL_TRESPASS[CRIMINAL_TRESPASS['Location Description']=='STREET']
OFFENSE_INVOLVING_CHILDREN_loc = OFFENSE_INVOLVING_CHILDREN[OFFENSE_INVOLVING_CHILDREN['Location Description']=='STREET']
CRIMINAL_SEXUAL_ASSAULT_loc = CRIMINAL_SEXUAL_ASSAULT[CRIMINAL_SEXUAL_ASSAULT['Location Description']=='STREET']
SEX_OFFENSE_loc = SEX_OFFENSE[SEX_OFFENSE['Location Description']=='STREET']
PUBLIC_PEACE_VIOLATION_loc = PUBLIC_PEACE_VIOLATION[PUBLIC_PEACE_VIOLATION['Location Description']=='STREET']
INTERFERENCE_WITH_PUBLIC_OFFICER_loc = INTERFERENCE_WITH_PUBLIC_OFFICER[INTERFERENCE_WITH_PUBLIC_OFFICER['Location Description']=='STREET']
HOMICIDE_loc = HOMICIDE[HOMICIDE['Location Description']=='STREET']
STALKING_loc = STALKING[STALKING['Location Description']=='STREET']
ARSON_loc = ARSON[ARSON['Location Description']=='STREET']
PROSTITUTION_loc = PROSTITUTION[PROSTITUTION['Location Description']=='STREET']
CONCEALED_CARRY_LICENSE_VIOLATION_loc = CONCEALED_CARRY_LICENSE_VIOLATION[CONCEALED_CARRY_LICENSE_VIOLATION['Location Description']=='STREET']
INTIMIDATION_loc = INTIMIDATION[INTIMIDATION['Location Description']=='STREET']
KIDNAPPING_loc = KIDNAPPING[KIDNAPPING['Location Description']=='STREET']
OBSCENITY_loc = OBSCENITY[OBSCENITY['Location Description']=='STREET']
HUMAN_TRAFFICKING_loc = HUMAN_TRAFFICKING[HUMAN_TRAFFICKING['Location Description']=='STREET']
GAMBLING_loc = GAMBLING[GAMBLING['Location Description']=='STREET']
PUBLIC_INDECENCY_loc = PUBLIC_INDECENCY[PUBLIC_INDECENCY['Location Description']=='STREET']
OTHER_NARCOTIC_VIOLATION_loc = OTHER_NARCOTIC_VIOLATION[OTHER_NARCOTIC_VIOLATION['Location Description']=='STREET']
NON_CRIMINAL_loc = NON_CRIMINAL[NON_CRIMINAL['Location Description']=='STREET']

# %%
year_tl = theft_loc[theft_loc['Year']==2025]
year_bl = battery_loc[battery_loc['Year']==2025]
year_cd = cd_loc[cd_loc['Year']==2025]
year_ass= ASSAULT_loc[ASSAULT_loc['Year']==2025]
year_mvt = MOTOR_VEHICLE_THEFT_loc[MOTOR_VEHICLE_THEFT_loc['Year']==2025]
year_of = OTHER_OFFENSE_loc[OTHER_OFFENSE_loc['Year']==2025]
year_dp = DECEPTIVE_PRACTICE_loc[DECEPTIVE_PRACTICE_loc['Year']==2025]
year_bur = BURGLARY_loc[BURGLARY_loc['Year']==2025]
year_rob = ROBBERY_loc[ROBBERY_loc['Year']==2025]
year_wv = WEAPONS_VIOLATION_loc[WEAPONS_VIOLATION_loc['Year']==2025]
year_nc = NARCOTICS_loc[NARCOTICS_loc['Year']==2025]
year_ct = CRIMINAL_TRESPASS_loc[CRIMINAL_TRESPASS_loc['Year']==2025]
year_oic = OFFENSE_INVOLVING_CHILDREN_loc[OFFENSE_INVOLVING_CHILDREN_loc['Year']==2025]
year_csa = CRIMINAL_SEXUAL_ASSAULT_loc[CRIMINAL_SEXUAL_ASSAULT_loc['Year']==2025]

#for whole year 2025
year_so = SEX_OFFENSE_loc[SEX_OFFENSE_loc['Year']==2025]
year_ppv= PUBLIC_PEACE_VIOLATION_loc[PUBLIC_PEACE_VIOLATION_loc['Year']==2025]
year_ipo= INTERFERENCE_WITH_PUBLIC_OFFICER_loc[INTERFERENCE_WITH_PUBLIC_OFFICER_loc['Year']==2025]
year_ho= HOMICIDE_loc[HOMICIDE_loc['Year']==2025]
year_st= STALKING_loc[STALKING_loc['Year']==2025]
year_ar= ARSON_loc[ARSON_loc['Year']==2025]
year_pros= PROSTITUTION_loc[PROSTITUTION_loc['Year']==2025]
year_int= INTIMIDATION_loc[INTIMIDATION_loc['Year']==2025]
year_kid= KIDNAPPING_loc[KIDNAPPING_loc['Year']==2025]
year_cclv= CONCEALED_CARRY_LICENSE_VIOLATION_loc[CONCEALED_CARRY_LICENSE_VIOLATION_loc['Year']==2025]
year_obs= OBSCENITY_loc[OBSCENITY_loc['Year']==2025]
year_ht= HUMAN_TRAFFICKING_loc[HUMAN_TRAFFICKING_loc['Year']==2025]
year_gam= GAMBLING_loc[GAMBLING_loc['Year']==2025]
year_pi= PUBLIC_INDECENCY_loc[PUBLIC_INDECENCY_loc['Year']==2025]
year_onv= OTHER_NARCOTIC_VIOLATION_loc[OTHER_NARCOTIC_VIOLATION_loc['Year']==2025]
year_ncl= NON_CRIMINAL_loc[NON_CRIMINAL_loc['Year']==2025]

# %%
month_tl = year_tl[year_tl['Month'] == 1]
month_bl = year_bl[year_bl['Month'] == 1]
month_cd  = year_cd[year_cd['Month'] == 1]
month_ass  = year_ass[year_ass['Month'] == 1]
month_mvt  = year_mvt[year_mvt['Month'] == 1]
month_of  = year_of[year_of['Month'] == 1]
month_dp  = year_dp[year_dp['Month'] == 1]
month_bur  = year_bur[year_bur['Month'] == 1]
month_rob  = year_rob[year_rob['Month'] == 1]
month_wv  = year_wv[year_wv['Month'] == 1]
month_nc  = year_nc[year_nc['Month'] == 1]
month_ct  = year_ct[year_ct['Month'] == 1]
month_oic  = year_oic[year_oic['Month'] == 1]
month_csa  = year_csa[year_csa['Month'] == 1]

# %%
#for january only of 2025

theft_final = month_tl.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
battery_final = month_bl.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
cd_final = month_cd.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ass_final = month_ass.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
mvt_final = month_mvt.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
of_final = month_of.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
dp_final = month_dp.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
bur_final = month_bur.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
rob_final = month_rob.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
wv_final = month_wv.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
nc_final = month_nc.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ct_final = month_ct.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
oic_final = month_oic.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
csa_final = month_csa.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')

#Year 2025 only
os_final = year_so.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ppv_final = year_ppv.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ipo_final = year_ipo.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ho_final = year_ho.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
st_final = year_st.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ar_final = year_ar.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
pros_final = year_pros.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
int_final = year_int.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
cclv_final = year_cclv.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
kid_final = year_kid.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
obs_final = year_obs.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ht_final = year_ht.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
gam_final = year_gam.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
pi_final = year_pi.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
onv_final = year_onv.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')
ncl_final = year_ncl.groupby(['Latitude','Longitude']).size().reset_index(name='incident_count')

# %%
#for January Only of 2025

theft_final['normalize_data'] = theft_final['incident_count'] - theft_final['incident_count'].min() / theft_final['incident_count'].max() - theft_final['incident_count'].min()
theft_data = theft_final[['Latitude','Longitude','normalize_data']].values.tolist()

battery_final['normalize_data'] = battery_final['incident_count'] - battery_final['incident_count'].min() / battery_final['incident_count'].max() - battery_final['incident_count'].min()
battery_data = battery_final[['Latitude','Longitude','normalize_data']].values.tolist()

cd_final['normalize_data'] = cd_final['incident_count'] - cd_final['incident_count'].min() / cd_final['incident_count'].max() - cd_final['incident_count'].min()
cd_data = cd_final[['Latitude','Longitude','normalize_data']].values.tolist()

ass_final['normalize_data'] = ass_final['incident_count'] - ass_final['incident_count'].min() / ass_final['incident_count'].max() - ass_final['incident_count'].min()
ass_data = ass_final[['Latitude','Longitude','normalize_data']].values.tolist()

mvt_final['normalize_data'] = mvt_final['incident_count'] - mvt_final['incident_count'].min() / mvt_final['incident_count'].max() - mvt_final['incident_count'].min()
mvt_data = mvt_final[['Latitude','Longitude','normalize_data']].values.tolist()

of_final['normalize_data'] = of_final['incident_count'] - of_final['incident_count'].min() / of_final['incident_count'].max() - of_final['incident_count'].min()
of_data = of_final[['Latitude','Longitude','normalize_data']].values.tolist()

dp_final['normalize_data'] = dp_final['incident_count'] - dp_final['incident_count'].min() / dp_final['incident_count'].max() - dp_final['incident_count'].min()
dp_data = dp_final[['Latitude','Longitude','normalize_data']].values.tolist()

bur_final['normalize_data'] = bur_final['incident_count'] - bur_final['incident_count'].min() / bur_final['incident_count'].max() - bur_final['incident_count'].min()
bur_data = bur_final[['Latitude','Longitude','normalize_data']].values.tolist()

rob_final['normalize_data'] = rob_final['incident_count'] - rob_final['incident_count'].min() / rob_final['incident_count'].max() - rob_final['incident_count'].min()
rob_data = rob_final[['Latitude','Longitude','normalize_data']].values.tolist()

wv_final['normalize_data'] = wv_final['incident_count'] - wv_final['incident_count'].min() / wv_final['incident_count'].max() - wv_final['incident_count'].min()
wv_data = wv_final[['Latitude','Longitude','normalize_data']].values.tolist()

nc_final['normalize_data'] = nc_final['incident_count'] - nc_final['incident_count'].min() / nc_final['incident_count'].max() - nc_final['incident_count'].min()
nc_data = nc_final[['Latitude','Longitude','normalize_data']].values.tolist()

ct_final['normalize_data'] = ct_final['incident_count'] - ct_final['incident_count'].min() / ct_final['incident_count'].max() - ct_final['incident_count'].min()
ct_data = ct_final[['Latitude','Longitude','normalize_data']].values.tolist()

oic_final['normalize_data'] = oic_final['incident_count'] - oic_final['incident_count'].min() / oic_final['incident_count'].max() - oic_final['incident_count'].min()
oic_data = oic_final[['Latitude','Longitude','normalize_data']].values.tolist()

csa_final['normalize_data'] = csa_final['incident_count'] - csa_final['incident_count'].min() / csa_final['incident_count'].max() - csa_final['incident_count'].min()
csa_data = csa_final[['Latitude','Longitude','normalize_data']].values.tolist()

#for whole 2025

os_final['normalize_data'] = os_final['incident_count'] - os_final['incident_count'].min() / os_final['incident_count'].max() - os_final['incident_count'].min()
os_data = os_final[['Latitude','Longitude','normalize_data']].values.tolist()

ppv_final['normalize_data'] = ppv_final['incident_count'] - ppv_final['incident_count'].min() / ppv_final['incident_count'].max() - ppv_final['incident_count'].min()
ppv_data = ppv_final[['Latitude','Longitude','normalize_data']].values.tolist()

ipo_final['normalize_data'] = ipo_final['incident_count'] - ipo_final['incident_count'].min() / ipo_final['incident_count'].max() - ipo_final['incident_count'].min()
ipo_data = ipo_final[['Latitude','Longitude','normalize_data']].values.tolist()

ho_final['normalize_data'] = ho_final['incident_count'] - ho_final['incident_count'].min() / ho_final['incident_count'].max() - ho_final['incident_count'].min()
ho_data = ho_final[['Latitude','Longitude','normalize_data']].values.tolist()

st_final['normalize_data'] = st_final['incident_count'] - st_final['incident_count'].min() / st_final['incident_count'].max() - st_final['incident_count'].min()
st_data = st_final[['Latitude','Longitude','normalize_data']].values.tolist()

ar_final['normalize_data'] = ar_final['incident_count'] - ar_final['incident_count'].min() / ar_final['incident_count'].max() - ar_final['incident_count'].min()
ar_data = ar_final[['Latitude','Longitude','normalize_data']].values.tolist()

pros_final['normalize_data'] = pros_final['incident_count'] - pros_final['incident_count'].min() / pros_final['incident_count'].max() - pros_final['incident_count'].min()
pros_data = pros_final[['Latitude','Longitude','normalize_data']].values.tolist()

int_final['normalize_data'] = int_final['incident_count'] - int_final['incident_count'].min() / int_final['incident_count'].max() - int_final['incident_count'].min()
int_data = int_final[['Latitude','Longitude','normalize_data']].values.tolist()

cclv_final['normalize_data'] = cclv_final['incident_count'] - cclv_final['incident_count'].min() / cclv_final['incident_count'].max() - cclv_final['incident_count'].min()
cclv_data = cclv_final[['Latitude','Longitude','normalize_data']].values.tolist()

kid_final['normalize_data'] = kid_final['incident_count'] - kid_final['incident_count'].min() / kid_final['incident_count'].max() - kid_final['incident_count'].min()
kid_data = kid_final[['Latitude','Longitude','normalize_data']].values.tolist()

obs_final['normalize_data'] = obs_final['incident_count'] - obs_final['incident_count'].min() / obs_final['incident_count'].max() - obs_final['incident_count'].min()
obs_data = obs_final[['Latitude','Longitude','normalize_data']].values.tolist()

ht_final['normalize_data'] = ht_final['incident_count'] - ht_final['incident_count'].min() / ht_final['incident_count'].max() - ht_final['incident_count'].min()
ht_data = ht_final[['Latitude','Longitude','normalize_data']].values.tolist()

gam_final['normalize_data'] = gam_final['incident_count'] - gam_final['incident_count'].min() / gam_final['incident_count'].max() - gam_final['incident_count'].min()
gam_data = gam_final[['Latitude','Longitude','normalize_data']].values.tolist()

pi_final['normalize_data'] = pi_final['incident_count'] - pi_final['incident_count'].min() / pi_final['incident_count'].max() - pi_final['incident_count'].min()
pi_data = pi_final[['Latitude','Longitude','normalize_data']].values.tolist()

onv_final['normalize_data'] = onv_final['incident_count'] - onv_final['incident_count'].min() / onv_final['incident_count'].max() - onv_final['incident_count'].min()
onv_data = onv_final[['Latitude','Longitude','normalize_data']].values.tolist()

ncl_final['normalize_data'] = ncl_final['incident_count'] - ncl_final['incident_count'].min() / ncl_final['incident_count'].max() - ncl_final['incident_count'].min()
ncl_data = ncl_final[['Latitude','Longitude','normalize_data']].values.tolist()

# %%
theft_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
battery_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
cd_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ass_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
mvt_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
of_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
dp_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
bur_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
rob_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
wv_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
nc_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ct_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
oic_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
csa_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)

#For whole 2025
os_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ppv_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ipo_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ho_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
st_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ar_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
pros_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
int_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
cclv_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
kid_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
obs_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ht_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
gam_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
pi_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
onv_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
ncl_map = folium.Map(location=[41.8781, -87.6298], zoom_start=10)

# %%
HeatMap(theft_data).add_to(theft_map)
HeatMap(battery_data).add_to(battery_map)
HeatMap(cd_data).add_to(cd_map)
HeatMap(ass_data).add_to(ass_map)
HeatMap(mvt_data).add_to(mvt_map)
HeatMap(of_data).add_to(of_map)
HeatMap(dp_data).add_to(dp_map)
HeatMap(bur_data).add_to(bur_map)
HeatMap(rob_data).add_to(rob_map)
HeatMap(wv_data).add_to(wv_map)
HeatMap(nc_data).add_to(nc_map)
HeatMap(ct_data).add_to(ct_map)
HeatMap(oic_data).add_to(oic_map)
HeatMap(csa_data).add_to(csa_map)

#for whole 2025
HeatMap(os_data).add_to(os_map)
HeatMap(ppv_data).add_to(ppv_map)
HeatMap(ipo_data).add_to(ipo_map)
HeatMap(ho_data).add_to(ho_map)
HeatMap(st_data).add_to(st_map)
HeatMap(ar_data).add_to(ar_map)
HeatMap(pros_data).add_to(pros_map)
HeatMap(int_data).add_to(int_map)
HeatMap(cclv_data).add_to(cclv_map)
HeatMap(kid_data).add_to(kid_map)
HeatMap(obs_data).add_to(obs_map)
HeatMap(ht_data).add_to(ht_map)
HeatMap(gam_data).add_to(gam_map)
HeatMap(pi_data).add_to(pi_map)
HeatMap(onv_data).add_to(onv_map)
HeatMap(ncl_data).add_to(ncl_map)

# %%
#for January ONly of 2025
theft_map.save('chicago_crimes.html')
battery_map.save('chicago_crimes.html')
cd_map.save('chicago_crimes.html')
ass_map.save('chicago_crimes.html')
mvt_map.save('chicago_crimes.html')
of_map.save('chicago_crimes.html')
dp_map.save('chicago_crimes.html')
bur_map.save('chicago_crimes.html')
rob_map.save('chicago_crimes.html')
wv_map.save('chicago_crimes.html')
nc_map.save('chicago_crimes.html')
ct_map.save('chicago_crimes.html')
oic_map.save('chicago_crimes.html')
csa_map.save('chicago_crimes.html')

#for whole 2025
os_map.save('chicago_crimes.html')
ppv_map.save('chicago_crimes.html')
ipo_map.save('chicago_crimes.html')
ho_map.save('chicago_crimes.html')
st_map.save('chicago_crimes.html')
ar_map.save('chicago_crimes.html')
pros_map.save('chicago_crimes.html')
cclv_map.save('chicago_crimes.html')
int_map.save('chicago_crimes.html')
kid_map.save('chicago_crimes.html')
obs_map.save('chicago_crimes.html')
ht_map.save('chicago_crimes.html')
gam_map.save('chicago_crimes.html')
pi_map.save('chicago_crimes.html')
onv_map.save('chicago_crimes.html')
ncl_map.save('chicago_crimes.html')

# %% [markdown]
# <h1>Different type of Crimes in the <strong>Street<strong> of Chicago during <strong>January only of 2025<strong></h1>

# %%
theft_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
battery_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
cd_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ass_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
mvt_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
of_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
dp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
bur_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
rob_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
wv_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
nc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ct_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
oic_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
csa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>Different Cases in Streets in Whole Year 2025</h1>

# %%
os_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ppv_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ipo_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ho_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
st_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ar_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
pros_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
cclv_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
int_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
kid_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
obs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ht_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gam_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
pi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
onv_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ncl_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
